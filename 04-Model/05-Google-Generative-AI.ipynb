# %% [markdown]
# # Google AI chat models (gemini-pro)
#
# Google AI의 `gemini`와 `gemini-vision` 모델뿐만 아니라 다른 생성 모델에 접근하려면 [langchain-google-genai](https://pypi.org/project/langchain-google-genai/) 통합 패키지의 `ChatGoogleGenerativeAI` 클래스를 사용하면 됩니다.

# %%
# !pip install -qU langchain-google-genai

# %% [markdown]
# ### API KEY 발급받기
#
# - [링크](https://makersuite.google.com/app/apikey?hl=ko) 에서 API KEY를 발급받아주세요.
# - 사용자의 Google API 키를 환경 변수 `GOOGLE_API_KEY`로 설정합니다.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# LangSmith 추적을 설정합니다. https://smith.langchain.com
# !pip install langchain-teddynote
from langchain_teddynote import logging
from langchain_teddynote.messages import stream_response

# 프로젝트 이름을 입력합니다.
logging.langsmith("CH04-Models")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# CH04-Models

# %% [markdown]
# langchain_google_genai 패키지에서 ChatGoogleGenerativeAI 클래스를 가져옵니다.
#
# - ChatGoogleGenerativeAI 클래스는 Google의 Generative AI 모델을 사용하여 대화형 AI 시스템을 구현하는 데 사용됩니다.
# - 이 클래스를 통해 사용자는 Google의 대화형 AI 모델과 상호 작용할 수 있습니다.
# - 모델과의 대화는 채팅 형식으로 이루어지며, 사용자의 입력에 따라 모델이 적절한 응답을 생성합니다.
# - ChatGoogleGenerativeAI 클래스는 LangChain 프레임워크와 통합되어 있어, 다른 LangChain 컴포넌트와 함께 사용할 수 있습니다.

# %% [markdown]
# 지원되는 모델 정보: https://ai.google.dev/gemini-api/docs/models/gemini?hl=ko

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# ChatGoogleGenerativeAI 언어 모델을 초기화합니다.
llm = ChatGoogleGenerativeAI(model="gemini-1.5-pro-latest")

# 프롬프트를 전달하여 결과를 생성합니다.
answer = llm.stream("자연어처리에 대해서 간략히 설명해 줘")

# 결과를 출력합니다.
stream_response(answer)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream. Similarly, direct use of AFC in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message.
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\langchain_google_genai\chat_models.py:363, in _classified_stream(response, request)
#     362 try:
# --> 363     yield from response
#     364 except ClientError as e:
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\google\genai\models.py:6448, in Models.generate_content_stream(self, model, contents, config)
#    6446 chunk = None
# -> 6448 for chunk in response:
#    6449   if (
#    6450       _extra_utils.should_append_afc_history(parsed_config)
#    6451       and automatic_function_calling_history
#    6452   ):
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\google\genai\models.py:4815, in Models._generate_content_stream(self, model, contents, config)
#    4810   raise ValueError(
#    4811       'Accessing the raw HTTP response is not supported in streaming'
#    4812       ' methods.'
#    4813   )
# -> 4815 for response in self._api_client.request_streamed(
#    4816     'post', path, request_dict, http_options
#    4817 ):
#    4819   response_dict = {} if not response.body else json.loads(response.body)
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\google\genai\_api_client.py:1767, in BaseApiClient.request_streamed(self, http_method, path, request_dict, http_options)
#    1763 http_request = self._build_request(
#    1764     http_method, path, request_dict, http_options
#    1765 )
# -> 1767 session_response = self._request(http_request, http_options, stream=True)
#    1768 for chunk in session_response.segments():
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\google\genai\_api_client.py:1535, in BaseApiClient._request(self, http_request, http_options, stream)
#    1534     retry = tenacity.Retrying(**retry_kwargs)
# -> 1535     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1537 return self._retry(self._request_once, http_request, stream)
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\tenacity\__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     392 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393     self._add_action_func(lambda rs: rs.outcome.result())
#     394     return
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\google\genai\_api_client.py:1514, in BaseApiClient._request_once(self, http_request, stream)
#    1513   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr, arg-type]
# -> 1514 errors.APIError.raise_for_response(response)
#    1515 return HttpResponse(
#    1516     response.headers, response if stream else [response.text]
#    1517 )
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\google\genai\errors.py:173, in APIError.raise_for_response(cls, response)
#     171   response_json = response.body_segments[0].get('error', {})
# --> 173 cls.raise_error(response.status_code, response_json, response)
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\google\genai\errors.py:202, in APIError.raise_error(cls, status_code, response_json, response)
#     201 if 400 <= status_code < 500:
# --> 202   raise ClientError(status_code, response_json, response)
#     203 elif 500 <= status_code < 600:
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/gemini-1.5-pro-latest is not found for API version v1beta, or is not supported for generateContent. Call ModelService.ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}
#
# The above exception was the direct cause of the following exception:
#
# GoogleModelNotFoundError                  Traceback (most recent call last)
# Cell In[8], line 10
#       6 # 프롬프트를 전달하여 결과를 생성합니다.
#       7 answer = llm.stream("자연어처리에 대해서 간략히 설명해 줘")
#       8
#       9 # 결과를 출력합니다.
# ---> 10 stream_response(answer)
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\langchain_teddynote\messages.py:32, in stream_response(response, return_output)
#      17 """
#      18 AI 모델로부터의 응답을 스트리밍하여 각 청크를 처리하면서 출력합니다.
#      19
#    (...)     29 - str: `return_output`이 True인 경우, 연결된 응답 문자열입니다. 그렇지 않으면, 아무것도 반환되지 않습니다.
#      30 """
#      31 answer = ""
# ---> 32 for token in response:
#      33     if isinstance(token, AIMessageChunk):
#      34         answer += token.content
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\langchain_core\language_models\chat_models.py:794, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     792 index = -1
#     793 index_type = ""
# --> 794 for chunk in self._stream(input_messages, stop=stop, **kwargs):
#     795     if chunk.message.id is None:
#     796         chunk.message.id = run_id
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\langchain_google_genai\chat_models.py:4270, in ChatGoogleGenerativeAI._stream(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    4268 prev_usage_metadata: UsageMetadata | None = None  # Cumulative usage
#    4269 indexer = _StreamBlockIndexer()
# -> 4270 for chunk in _classified_stream(response, request):
#    4271     if chunk:
#    4272         _chat_result = _response_to_result(
#    4273             chunk, stream=True, prev_usage=prev_usage_metadata
#    4274         )
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\langchain_google_genai\chat_models.py:365, in _classified_stream(response, request)
#     363     yield from response
#     364 except ClientError as e:
# --> 365     _handle_client_error(e, request)
#     366 except ServerError as e:
#     367     _handle_server_error(e)
#
# File ~\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\langchain_google_genai\chat_models.py:326, in _handle_client_error(e, request)
#     324 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
#     325 if error_type := _CLIENT_ERROR_TYPES.get(e.code):
# --> 326     raise error_type(msg) from e
#     327 raise ChatGoogleGenerativeAIError(msg) from e
#
# GoogleModelNotFoundError: Error calling model 'gemini-1.5-pro-latest' (NOT_FOUND): 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/gemini-1.5-pro-latest is not found for API version v1beta, or is not supported for generateContent. Call ModelService.ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}

# %%
from langchain_core.prompts import PromptTemplate

# ChatGoogleGenerativeAI 언어 모델을 초기화합니다.
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",  # 사용할 모델을 지정합니다.
)

# 프롬프트를 생성합니다.
prompt = PromptTemplate.from_template(
    "예/아니오 질문에 대답하세요. {question}는 과일입니까?"
)

# 체인을 생성합니다.
chain = prompt | model

# 결과를 출력합니다.
stream_response(chain.stream({"question": "사과"}))
# Out:
# 예

# %% [markdown]
# ## Safety Settings
#
# Gemini 모델에는 기본 안전 설정(Satety Settings) 이 있지만, 이를 재정의할 수 있습니다.
#
# 만약 모델로부터 많은 "Safety Warnings"를 받고 있다면, 모델의 `safety_settings` 속성을 조정해 볼 수 있습니다.
#
# Google의 [Safety Setting Types](https://ai.google.dev/api/python/google/generativeai/types/SafetySettingDict) 문서에서는 사용 가능한 카테고리와 임계값에 대한 열거형 정보를 제공합니다.
#
# 이 문서에는 콘텐츠 필터링 및 안전 설정과 관련된 다양한 카테고리와 해당 임계값이 정의되어 있어, 개발자들이 생성형 AI 모델을 활용할 때 적절한 안전 설정을 선택하고 적용하는 데 도움을 줍니다.
#
# 이를 통해 개발자들은 모델이 생성하는 콘텐츠의 안전성과 적절성을 보장하고, 사용자에게 유해하거나 부적절한 내용이 노출되는 것을 방지할 수 있습니다.

# %%
from langchain_google_genai import (
    ChatGoogleGenerativeAI,
    # 얼마나 위험하다고 판단되었을 때 차단할 것인지
    HarmBlockThreshold,
    # 유해 콘텐츠의 종류
    HarmCategory,
)

llm = ChatGoogleGenerativeAI(
    # 사용할 모델을 "gemini-pro"로 지정합니다.
    model="gemini-1.5-pro-latest",
    safety_settings={
        # 위험한 콘텐츠에 대한 차단 임계값을 설정합니다.
        # 이 경우 위험한 콘텐츠를 차단하지 않도록 설정되어 있습니다. (그럼에도 기본적인 차단이 있을 수 있습니다.)
        HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
        HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
    },
)

# %% [markdown]
# ## Batch 단위 실행

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    # 사용할 모델을 "gemini-pro"로 지정합니다.
    model="gemini-1.5-pro-latest",
)

results = llm.batch(
    [
        "대한민국의 수도는?",
        "대한민국의 주요 관광지 5곳을 나열하세요",
    ]
)

for res in results:
    # 각 결과의 내용을 출력합니다.
    print(res.content)

# %% [markdown]
# ## Multimodal 모델
#
# `langchain-teddynote` 에서 구현한 멀티모달 모델에 `gemini-1.5-pro` 모델을 활용하여 이미지를 텍스트로 변환 가능합니다.

# %%
from langchain_teddynote.models import MultiModal
from langchain_teddynote.messages import stream_response

# 객체 생성
gemini = ChatGoogleGenerativeAI(model="gemini-1.5-pro-latest")

system_prompt = (
    "당신은 시인입니다. 당신의 임무는 주어진 이미지를 가지고 시를 작성하는 것입니다."
)

user_prompt = "다음의 이미지에 대한 시를 작성해주세요."

# 멀티모달 객체 생성
multimodal_gemini = MultiModal(
    llm, system_prompt=system_prompt, user_prompt=user_prompt
)

# %%
# 샘플 이미지 경로(파일의 경로, URL 등)를 지정합니다.
IMAGE_URL = "images/jeju-beach.jpg"

# 이미지 파일로 부터 질의
answer = multimodal_gemini.stream(IMAGE_URL)

# 스트리밍 방식으로 각 토큰을 출력합니다. (실시간 출력)
stream_response(answer)
